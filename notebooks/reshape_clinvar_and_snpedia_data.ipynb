# %%
import pandas as pd

# %%
clinvar_path = "../../snpedia-nlp/genes_and_diseases.tsv"
snippets_path = "../../snpedia-nlp/genes_snps_snippets.tsv"
contexts_path = "../../snpedia-nlp/genes_snps_contexts.tsv"

# %%
df = pd.read_csv(clinvar_path, sep="\t", header=0, names=["unique_gene_identifiers", "descriptions"])
df["species"] = "hsa"
df["other_gene_identifiers"] = ""
df["gene_models"] = ""
df["sources"] = "ClinVar"
df["annotations"] = ""
df.to_csv("../data/clinvar/clinvar_diseases.csv")
df
# Out:
#      unique_gene_identifiers                              descriptions  \
# 0                        A2M                         Alzheimer disease
# 1                      A2ML1           Otitis media, susceptibility to
# 2                     A4GALT                               p phenotype
# 3                       AAAS  Glucocorticoid deficiency with achalasia
# 4                      AAGAB         Keratosis palmoplantaris papulosa
# ...                      ...                                       ...
# 9547                   ZFP57                Neonatal diabetes mellitus
# 9548                    ZIC2                Holoprosencephaly sequence
# 9549                 ZMYND10                Primary ciliary dyskinesia
# 9550                  ZNF335  Primary autosomal recessive microcephaly
# 9551                  ZNF513                      Retinitis pigmentosa
#
#      species other_gene_identifiers gene_models  sources annotations
# 0        hsa                                     ClinVar
# 1        hsa                                     ClinVar
# 2        hsa                                     ClinVar
# 3        hsa                                     ClinVar
# 4        hsa                                     ClinVar
# ...      ...                    ...         ...      ...         ...
# 9547     hsa                                     ClinVar
# 9548     hsa                                     ClinVar
# 9549     hsa                                     ClinVar
# 9550     hsa                                     ClinVar
# 9551     hsa                                     ClinVar
#
# [9552 rows x 7 columns]

# %%
df = pd.read_csv(snippets_path, sep="\t", header=0, names=["unique_gene_identifiers", "other_gene_identifiers", "descriptions"])
df["species"] = "hsa"
df["gene_models"] = ""
df["sources"] = "SNPedia"
df["annotations"] = ""
df.to_csv("../data/snpedia/snpedia_snippets.csv")
df
# Out:
#       unique_gene_identifiers other_gene_identifiers  \
# 0                       AANAT              Rs3760138
# 1                       ABCA1              Rs2230808
# 2                       ABCA1              Rs2230808
# 3                       ABCA1              Rs2230808
# 4                       ABCA1              Rs2230808
# ...                       ...                    ...
# 22762                 ZSCAN25             Rs45446698
# 22763                 ZSCAN25             Rs45593941
# 22764                 ZSCAN25             Rs45593941
# 22765                 ZSCAN25             Rs45593941
# 22766                 ZSCAN25               Rs776746
#
#                                             descriptions species gene_models  \
# 0                                                 autism     hsa
# 1                                    Alzheimer's disease     hsa
# 2                 polymorphisms and Alzheimer's disease.     hsa
# 3               schizophrenia and related brain changes.     hsa
# 4                                           polymorphism     hsa
# ...                                                  ...     ...         ...
# 22762  increased risk of breast cancer, lung cancer, ...     hsa
# 22763                                         rs45593941     hsa
# 22764                                               L82R     hsa
# 22765                                        CYP3A5 gene     hsa
# 22766                                     nephrotoxicity     hsa
#
#        sources annotations
# 0      SNPedia
# 1      SNPedia
# 2      SNPedia
# 3      SNPedia
# 4      SNPedia
# ...        ...         ...
# 22762  SNPedia
# 22763  SNPedia
# 22764  SNPedia
# 22765  SNPedia
# 22766  SNPedia
#
# [22767 rows x 7 columns]

# %%
df = pd.read_csv(contexts_path, sep="\t", header=0, names=["unique_gene_identifiers", "other_gene_identifiers", "descriptions"])
df["species"] = "hsa"
df["gene_models"] = ""
df["sources"] = "SNPedia"
df["annotations"] = ""
df.to_csv("../data/snpedia/snpedia_contexts.csv")
df
# Out:
#      unique_gene_identifiers other_gene_identifiers  \
# 0                      AANAT              Rs3760138
# 1                      ABCA1              Rs2297404
# 2                      ABCA1              Rs2230808
# 3                      ABCA1              Rs2230806
# 4                      ABCA1              Rs4149268
# ...                      ...                    ...
# 5913                 ZNF804A              Rs1344706
# 5914                 ZSCAN25             Rs45446698
# 5915                 ZSCAN25             Rs45593941
# 5916                 ZSCAN25             Rs10264272
# 5917                 ZSCAN25               Rs776746
#
#                                            descriptions species gene_models  \
# 0     Examination of association of genes in the ser...     hsa
# 1     rs2297404, rs2230808, and rs2020927 haplotype ...     hsa
# 2     A polymorphism of the ABCA1 gene confers susce...     hsa
# 3     Increase in HDL-C concentration by a dietary p...     hsa
# 4     G allele is associated with 0.82mg/dl increase...     hsa
# ...                                                 ...     ...         ...
# 5913  Evaluation of risk loci for schizophrenia deri...     hsa
# 5914  However, individuals with one of more copy of ...     hsa
# 5915    NOTE: this SNP has been merged into rs28365085.     hsa
# 5916  This does not correspond with dbSNP, which ind...     hsa
# 5917  Expression of CYP3A5 and P-glycoprotein in ren...     hsa
#
#       sources annotations
# 0     SNPedia
# 1     SNPedia
# 2     SNPedia
# 3     SNPedia
# 4     SNPedia
# ...       ...         ...
# 5913  SNPedia
# 5914  SNPedia
# 5915  SNPedia
# 5916  SNPedia
# 5917  SNPedia
#
# [5918 rows x 7 columns]
