# %%
import pandas as pd

# %%
clinvar_path = "../../snpedia-nlp/genes_and_diseases.tsv"
snippets_path = "../../snpedia-nlp/genes_snps_snippets.tsv"
contexts_path = "../../snpedia-nlp/genes_snps_contexts.tsv"

# %%
df = pd.read_csv(clinvar_path, sep="\t", header=0, names=["unique_gene_identifiers", "descriptions"])
df["species"] = "hsa"
df["other_gene_identifiers"] = ""
df["gene_models"] = ""
df["sources"] = "ClinVar"
df["annotations"] = ""
df.to_csv("../data/clinvar/diseases.csv")
df
# Out:
#      unique_gene_identifiers                              descriptions  \
# 0                        A2M                         Alzheimer disease
# 1                      A2ML1           Otitis media, susceptibility to
# 2                     A4GALT                               p phenotype
# 3                       AAAS  Glucocorticoid deficiency with achalasia
# 4                      AAGAB         Keratosis palmoplantaris papulosa
# ...                      ...                                       ...
# 9547                   ZFP57                Neonatal diabetes mellitus
# 9548                    ZIC2                Holoprosencephaly sequence
# 9549                 ZMYND10                Primary ciliary dyskinesia
# 9550                  ZNF335  Primary autosomal recessive microcephaly
# 9551                  ZNF513                      Retinitis pigmentosa
#
#      species other_gene_identifiers gene_models  sources annotations
# 0        hsa                                     ClinVar
# 1        hsa                                     ClinVar
# 2        hsa                                     ClinVar
# 3        hsa                                     ClinVar
# 4        hsa                                     ClinVar
# ...      ...                    ...         ...      ...         ...
# 9547     hsa                                     ClinVar
# 9548     hsa                                     ClinVar
# 9549     hsa                                     ClinVar
# 9550     hsa                                     ClinVar
# 9551     hsa                                     ClinVar
#
# [9552 rows x 7 columns]

# %%
df = pd.read_csv(snippets_path, sep="\t", header=0, names=["unique_gene_identifiers", "other_gene_identifiers", "descriptions"])
df["species"] = "hsa"
df["gene_models"] = ""
df["sources"] = "SNPedia"
df["annotations"] = ""
df.to_csv("../data/snpedia/snpedia_snippets.csv")
df
# Out:
#       unique_gene_identifiers other_gene_identifiers  \
# 0                       AANAT              Rs3760138
# 1                       AANAT              Rs3760138
# 2                       ABCA1              Rs2230808
# 3                       ABCA1              Rs2230808
# 4                       ABCA1              Rs2230808
# ...                       ...                    ...
# 20127                 ZSCAN25             Rs28365083
# 20128                 ZSCAN25             Rs28365083
# 20129                 ZSCAN25             Rs28365083
# 20130                 ZSCAN25             Rs28383468
# 20131                  ZSWIM6            Rs587777695
#
#                                       descriptions species gene_models  \
# 0                                           autism     hsa
# 1                                           autism     hsa
# 2                              Alzheimer's disease     hsa
# 3                              Alzheimer's disease     hsa
# 4           polymorphisms and Alzheimer's disease.     hsa
# ...                                            ...     ...         ...
# 20127                                      cancer      hsa
# 20128                           Gilbert's syndrome     hsa
# 20129         Pazopanib-induced hyperbilirubinemia     hsa
# 20130                                       allele     hsa
# 20131  mutation in the ZSWIM6 gene on chromosome 5     hsa
#
#        sources annotations
# 0      SNPedia
# 1      SNPedia
# 2      SNPedia
# 3      SNPedia
# 4      SNPedia
# ...        ...         ...
# 20127  SNPedia
# 20128  SNPedia
# 20129  SNPedia
# 20130  SNPedia
# 20131  SNPedia
#
# [20132 rows x 7 columns]

# %%
df = pd.read_csv(contexts_path, sep="\t", header=0, names=["unique_gene_identifiers", "other_gene_identifiers", "descriptions"])
df["species"] = "hsa"
df["gene_models"] = ""
df["sources"] = "SNPedia"
df["annotations"] = ""
df.to_csv("../data/snpedia/snpedia_contexts.csv")
df
# Out:
#      unique_gene_identifiers other_gene_identifiers  \
# 0                      AANAT              Rs3760138
# 1                      ABCA1              Rs2297404
# 2                      ABCA1              Rs2230808
# 3                      ABCA1              Rs2230806
# 4                      ABCA1              Rs4149268
# ...                      ...                    ...
# 4129                 ZSCAN25             Rs28365085
# 4130                 ZSCAN25             Rs28365083
# 4131                 ZSCAN25             Rs28365083
# 4132                 ZSCAN25             Rs28383468
# 4133                  ZSWIM6            Rs587777695
#
#                                            descriptions species gene_models  \
# 0     Examination of association of genes in the ser...     hsa
# 1     rs2297404, rs2230808, and rs2020927 haplotype ...     hsa
# 2     A polymorphism of the ABCA1 gene confers susce...     hsa
# 3     Increase in HDL-C concentration by a dietary p...     hsa
# 4     G allele is associated with 0.82mg/dl increase...     hsa
# ...                                                 ...     ...         ...
# 4129  rs45593941, also known as L82R, is a SNP in th...     hsa
# 4130  Genotyping panel for assessing response to can...     hsa
# 4131  Polymorphisms in the cytochrome P450 genes CYP...     hsa
# 4132  rs28383468, also known as 3705C>T or H30Y, is ...     hsa
# 4133  rs587777695, also known as R1163W, is a mutati...     hsa
#
#       sources annotations
# 0     SNPedia
# 1     SNPedia
# 2     SNPedia
# 3     SNPedia
# 4     SNPedia
# ...       ...         ...
# 4129  SNPedia
# 4130  SNPedia
# 4131  SNPedia
# 4132  SNPedia
# 4133  SNPedia
#
# [4134 rows x 7 columns]
