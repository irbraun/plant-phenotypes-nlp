# %%
import pandas as pd

# %%
clinvar_path = "../../snpedia-nlp/shared_genes_and_diseases.tsv"
snippets_path = "../../snpedia-nlp/shared_genes_snps_snippets.tsv"
contexts_path = "../../snpedia-nlp/shared_genes_snps_contexts.tsv"

# %%
df = pd.read_csv(clinvar_path, sep="\t", header=0, names=["unique_gene_identifiers", "descriptions"])
df["species"] = "hsa"
df["other_gene_identifiers"] = ""
df["gene_models"] = ""
df["sources"] = "ClinVar"
df["annotations"] = ""
df.to_csv("../data/clinvar/clinvar_diseases.csv")
df
# Out:
#      unique_gene_identifiers  \
# 0                      ABCA1
# 1                      ABCA1
# 2                     ABCA12
# 3                     ABCA12
# 4                      ABCA3
# ...                      ...
# 2999                     WT1
# 3000                     WT1
# 3001                     WT1
# 3002                     XPC
# 3003                   YARS2
#
#                                            descriptions species  \
# 0                     Familial hypoalphalipoproteinemia     hsa
# 1                                       Tangier disease     hsa
# 2          Autosomal recessive congenital ichthyosis 4B     hsa
# 3          Autosomal recessive congenital ichthyosis 4A     hsa
# 4       Surfactant metabolism dysfunction, pulmonary, 3     hsa
# ...                                                 ...     ...
# 2999  Hereditary Nephrotic Syndromes, Autosomal Domi...     hsa
# 3000                      Hereditary nephrotic syndrome     hsa
# ...

# %%
df = pd.read_csv(snippets_path, sep="\t", header=0, names=["unique_gene_identifiers", "other_gene_identifiers", "descriptions"])
df["species"] = "hsa"
df["gene_models"] = ""
df["sources"] = "SNPedia"
df["annotations"] = ""
df.to_csv("../data/snpedia/snpedia_snippets.csv")
df
# Out:
#       unique_gene_identifiers other_gene_identifiers  \
# 0                       ABCA1              Rs2230808
# 1                       ABCA1              Rs2230808
# 2                       ABCA1              Rs2230808
# 3                       ABCA1              Rs2230808
# 4                       ABCA1              Rs2230808
# ...                       ...                    ...
# 17611                  ZNF644            Rs587776903
# 17612                  ZNF644            Rs587776903
# 17613                  ZNF644            Rs587776903
# 17614                  ZNF644            Rs587776903
# 17615                  ZNF644            Rs587776903
#
#                                    descriptions species gene_models  sources  \
# 0                           Alzheimer's disease     hsa              SNPedia
# 1        polymorphisms and Alzheimer's disease.     hsa              SNPedia
# 2      schizophrenia and related brain changes.     hsa              SNPedia
# ...

# %%
df = pd.read_csv(contexts_path, sep="\t", header=0, names=["unique_gene_identifiers", "other_gene_identifiers", "descriptions"])
df["species"] = "hsa"
df["gene_models"] = ""
df["sources"] = "SNPedia"
df["annotations"] = ""
df.to_csv("../data/snpedia/snpedia_contexts.csv")
df
# Out:
#      unique_gene_identifiers other_gene_identifiers  \
# 0                      ABCA1              Rs2297404
# 1                      ABCA1              Rs2230808
# 2                      ABCA1              Rs2230806
# 3                      ABCA1              Rs4149268
# 4                      ABCA1              Rs2020927
# ...                      ...                    ...
# 4755                 XPNPEP2              Rs3788853
# 4756                 XPNPEP2            Rs138365897
# 4757                   YARS2             Rs11539445
# 4758                  ZNF644            Rs587776903
# 4759                  ZNF644            Rs769065721
#
#                                            descriptions species gene_models  \
# 0     rs2297404, rs2230808, and rs2020927 haplotype ...     hsa
# 1     A polymorphism of the ABCA1 gene confers susce...     hsa
# 2     Increase in HDL-C concentration by a dietary p...     hsa
# 3     G allele is associated with 0.82mg/dl increase...     hsa
# ...
